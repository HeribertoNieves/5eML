# %% [markdown]
# # Exploratory Data Analysis of 5e Spells Across Source Books

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import os

# %%
spell_sheet = os.path.expanduser(r'~/Documents/GitHub/5eML/Dataset/5e_spells Wikidot.csv')
pd.read_csv(spell_sheet)
# Out:
#                   name                          source         school  \
# 0          Acid Splash               Player's Handbook    Conjuration
# 1           Blade Ward               Player's Handbook     Abjuration
# 2        Booming Blade  Tasha's Cauldron of Everything      Evocation
# 3          Chill Touch               Player's Handbook     Necromancy
# 4       Control Flames  Xanathar's Guide to Everything  Transmutation
# ..                 ...                             ...            ...
# 575          Time Stop               Player's Handbook  transmutation
# 576     True Polymorph               Player's Handbook  transmutation
# 577  True Resurrection               Player's Handbook     necromancy
# 578              Weird               Player's Handbook       illusion
# 579               Wish               Player's Handbook    conjuration
#
#          level  ritual      time                 range  \
# 0      cantrip   False  1 action               60 feet
# ...

# %% [markdown]
# ### Expand Spell Lists
